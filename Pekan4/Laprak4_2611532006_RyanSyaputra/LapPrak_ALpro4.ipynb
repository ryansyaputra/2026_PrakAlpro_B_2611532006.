# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **Algoritma dan Pemrograman**
#
# **“Conditional pada python”**
#
# **Disusun Oleh :**
#
# **Ryan Syaputra**
#
# **2611532006**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Rifky Yuliandra**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Algoritma dan Pemrograman "Conditional pada Python" yang telah dilaksanakan sebagai pertemuan ke-4 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan jenis-jenis Conditional pada python yang ada pada bahasa pemrograman Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dasar Conditional pada Python bahasa pemrograman Python pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Algoritma dan pemrograman merupakan dasar utama dalam mempelajari ilmu komputer, karena melalui keduanya sebuah permasalahan dapat diterjemahkan menjadi langkah-langkah logis yang dapat dieksekusi oleh komputer. Salah satu bahasa pemrograman yang banyak digunakan untuk mempelajari konsep dasar tersebut adalah Python, karena memiliki sintaks yang sederhana, mudah dibaca, serta didukung oleh lingkungan kerja interaktif seperti Jupyter Notebook yang memungkinkan penulisan kode dan dokumentasi dilakukan secara bersamaan.
#
# Dalam setiap program, proses pengolahan data tidak dapat dilepaskan dari penggunaan operator. Operator adalah simbol khusus yang digunakan untuk melakukan operasi terhadap satu atau lebih nilai (operand), baik berupa operasi perhitungan, pemberian nilai, pembandingan, maupun pengambilan keputusan secara logika. Tanpa pemahaman yang benar mengenai operator, sebuah program berpotensi menghasilkan keluaran yang tidak sesuai dengan yang diharapkan meskipun secara sintaks tidak menimbulkan kesalahan.
#
# Python menyediakan beberapa jenis operator, yaitu operator aritmatika, operator penugasan, operator perbandingan, operator logika, operator bitwise, operator identitas, dan operator keanggotaan. Setiap jenis operator memiliki fungsi, aturan penulisan, serta tingkat prioritas (presedensi) yang berbeda-beda. Kesalahan dalam memahami urutan prioritas operator maupun perbedaan tipe data yang dioperasikan sering menjadi penyebab munculnya kesalahan logika pada program yang dibuat oleh pemula.
#
# Berdasarkan uraian tersebut, praktikum ini dilaksanakan untuk memberikan pemahaman secara langsung mengenai penggunaan berbagai jenis operator pada bahasa pemrograman Python. Melalui percobaan yang dilakukan pada Jupyter Notebook, praktikan diharapkan tidak hanya mengetahui teori mengenai operator, tetapi juga mampu menerapkannya dalam penyelesaian kasus pemrograman sederhana serta menganalisis hasil keluaran yang diperoleh.
#
#
# ## 1.2 Tujuan
# 1. Memahami fungsi dan mekanisme kerja berbagai jenis conditional dalam bahasa pemrograman Python.
# 2. Mengimplementasikan penggunaan operator if,elif,else ke dalam kode program.
# 3. Menganalisis perbedaan karakteristik serta tipe data hasil keluaran (output) dari masing-masing operator di lingkungan Jupyter Notebook.
#
# ## 1.3 Manfaat
# 1. Bagi praktikan, menambah pemahaman dan keterampilan dalam menggunakan operator Python sebagai dasar penyusunan program yang lebih kompleks.
# 2. Bagi pembaca, laporan ini dapat dijadikan sebagai bahan referensi dalam mempelajari materi operator pada bahasa pemrograman Python.
# 3. Hasil praktikum dapat menjadi dasar untuk mempelajari materi lanjutan seperti struktur kontrol percabangan dan perulangan.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
#
# Operator adalah simbol atau kata kunci khusus yang digunakan untuk melakukan suatu operasi terhadap satu atau lebih nilai. Nilai yang dioperasikan disebut operand, sedangkan gabungan antara operator dan operand disebut ekspresi. Pada ekspresi 7 + 3, simbol + berperan sebagai operator, sedangkan 7 dan 3 berperan sebagai operand. Berdasarkan jumlah operand yang dilibatkan, operator dibedakan menjadi operator unary yang hanya membutuhkan satu operand (misalnya -x) dan operator binary yang membutuhkan dua operand (misalnya x + y).
#
# Terdapat beberapa jenis operator dengan fungsi yang berbeda-beda. Operator aritmatika digunakan untuk melakukan perhitungan matematis, terdiri atas + (penjumlahan), - (pengurangan), * (perkalian), / (pembagian menghasilkan float), // (pembagian bulat), % (modulus atau sisa bagi), dan ** (perpangkatan). Operator perbandingan digunakan untuk membandingkan dua nilai dan menghasilkan tipe data boolean, meliputi ==, !=, >, <, >=, dan <=. Operator logika digunakan untuk menggabungkan beberapa ekspresi kondisional, terdiri atas and (benar jika kedua ekspresi benar), or (benar jika salah satu ekspresi benar), dan not (membalikkan nilai kebenaran). Operator bitwise digunakan untuk operasi pada tingkat bit suatu bilangan bulat, meliputi &, |, ^, ~, <<, dan >>. Operator identitas (is, is not) digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang sama di memori, berbeda dengan == yang membandingkan nilai. Adapun operator keanggotaan (in, not in) digunakan untuk memeriksa apakah suatu nilai terdapat di dalam struktur data seperti list, tuple, atau string.
#
# Ketika beberapa operator digunakan dalam satu ekspresi, urutan eksekusinya ditentukan oleh presedensi (prioritas) operator. Secara umum, urutan dari prioritas tertinggi ke terendah adalah tanda kurung (), perpangkatan **, operator unary, operator perkalian/pembagian (*, /, //, %), operator penjumlahan/pengurangan (+, -), operator bitwise, operator perbandingan, dan terakhir operator logika (and, or). Pemahaman terhadap urutan ini penting agar hasil suatu ekspresi dapat diprediksi dengan tepat, misalnya pada ekspresi 2 + 3 * 2 yang menghasilkan 8, bukan 10, karena perkalian dikerjakan lebih dahulu daripada penjumlahan.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Aritmatika_2611532006"

# %%
# Buat file dengan nama aritmatika_2611532006.py
# Buat program untuk operator aritmatika dalam python
# Nama variabel ditambah 4 digit nim terakhir contoh : angka_2006
# Program ini menggunakan fungsi input()

angka1_2006 = int(input("Input angka 1: "))
angka2_2006 = int(input("Input angka 2: "))

#Penjumlahan
hasil_2006 = angka1_2006 + angka2_2006
print("\nOperator Penjumlahan")
print("Hasil =", hasil_2006)

#Pengurangan
hasil_2006 = angka1_2006 - angka2_2006
print("\nOperator Pengurangan")
print("Hasil =", hasil_2006)

#Perkalian
hasil_2006 = angka1_2006 * angka2_2006
print("\nOperator Perkalian")
print("Hasil =", hasil_2006)

#Pembagian, pembagian bulat, dan sisa bagi
if angka2_2006 != 0:
    hasil_2006 = angka1_2006 / angka2_2006
    print("\nOperator Pembagian")
    print("Hasil =", hasil_2006)

    hasil_2006 = angka1_2006 // angka2_2006
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil_2006)

    hasil_2006 = angka1_2006 % angka2_2006
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil_2006)

#Pangkat
hasil_2006 = angka1_2006 ** angka2_2006
print("\nOperator Pangkat")
print("Hasil =", hasil_2006)

# %% [markdown]
# **Penjelasan :**
# 1. Program ini dibuat untuk mengimplementasikan seluruh operator aritmatika pada Python, yaitu penjumlahan, pengurangan, perkalian, pembagian, pembagian bulat, sisa bagi (modulus), dan perpangkatan.
#
# 2. Seluruh nama variabel diberi akhiran _2006 sesuai empat digit terakhir NIM, sebagai identitas bahwa program dibuat oleh praktikan yang bersangkutan.
#
# 3. Fungsi input() digunakan untuk meminta pengguna memasukkan dua nilai, yaitu angka1_2006 dan angka2_2006. Karena input() secara default mengembalikan tipe data string, nilai masukan dibungkus dengan fungsi int() agar diubah menjadi integer sehingga dapat digunakan dalam perhitungan matematis.
#
# 4. Operasi penjumlahan (+), pengurangan (-), dan perkalian (*) dijalankan terhadap kedua variabel, dengan hasil disimpan ke variabel hasil_2006 lalu ditampilkan menggunakan print().
#
# 5. Operasi pembagian (/), pembagian bulat (//), dan sisa bagi (%) diletakkan di dalam struktur kondisi if angka2_2006 != 0, yang berfungsi mencegah terjadinya error ZeroDivisionError apabila angka2_2006 bernilai nol.
#
# 6. Operasi perpangkatan (**) dijalankan pada bagian akhir program, yaitu memangkatkan angka1_2006 dengan angka2_2006, dan hasilnya ditampilkan sebagai keluaran terakhir.

# %% [markdown]
# ### 2.2.2 Program "Assignment_2611532006"

# %%
# Buat file dengan nama assignment_2611532006.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka_2006
# Program ini menggunakan funsgi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assignment dalam python

angka1_2006 = int(input("Input angka-1: "))
angka2_2006 = int(input("Input angka-2: "))

print("\nNilai awal angka1 =", angka1_2006)
print("Nilai angka2 =", angka2_2006)

# Assignment biasa
hasil_2006 = angka1_2006
print("\nAssignment biasa (=)")
print("hasil =", hasil_2006)

# Assignment penambahan
hasil_2006 = angka1_2006
hasil_2006 += angka2_2006
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_2006)

# Assignment pengurangan
hasil_2006 = angka1_2006
hasil_2006 -= angka2_2006
print("\nAssignment pengurangan (-=)")
print("Hasil =", hasil_2006)

# Assignment perkalian 
hasil_2006 = angka1_2006
hasil_2006 *= angka2_2006
print("\nAssignment perkalian (*=)")
print("hasil =", hasil_2006)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_2006 != 0:
    hasil_2006 = angka1_2006
    hasil_2006 /= angka2_2006
    print("\nAssignment pembagian (/=)")
    print("Hasil =", hasil_2006)
    # Operator tambahan
    hasil_2006 = angka1_2006
    hasil_2006 //= angka2_2006
    print("\nAssignment pembagian bulat (//=)")
    print("Hasil =", hasil_2006)
    hasil_2006 = angka1_2006
    hasil_2006 %= angka2_2006
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_2006)
else:
    print("\nPembagian tidak dapat dilakukan.")    
    print("Angka kedua tidak boleh bernilai 0")

# Operator tambahan: assignment perpangkatan
hasil_2006 = angka1_2006
hasil_2006 **= angka2_2006
print("\nAssignment perpangkatan (**=)")
print("Hasil =", hasil_2006)

# %% [markdown]
# **Penjelasan :**
# 1. Program ini dibuat untuk mengimplementasikan operator penugasan (assignment) pada Python, yaitu =, +=, -=, *=, /=, //=, %=, dan **=.
#
# 2. Seluruh nama variabel diberi akhiran _2006 sesuai empat digit terakhir NIM, sebagai identitas bahwa program dibuat oleh praktikan yang bersangkutan.
#
# 3. Fungsi input() digunakan untuk meminta pengguna memasukkan dua nilai, yaitu angka1_2006 dan angka2_2006, yang kemudian dikonversi menjadi tipe data integer menggunakan fungsi int().
#
# 4. Operator assignment biasa (=) digunakan untuk memberikan nilai angka1_2006 ke variabel hasil_2006 tanpa melakukan operasi apapun terhadap nilainya.
#
# 5. Operator assignment gabungan seperti += , -=, dan *= digunakan untuk melakukan operasi aritmatika sekaligus menyimpan hasilnya ke variabel yang sama. Misalnya hasil_2006 += angka2_2006 setara dengan hasil_2006 = hasil_2006 + angka2_2006.
#
# 6. Operator assignment pembagian (/=), pembagian bulat (//=), dan sisa bagi (%=) diletakkan di dalam struktur kondisi if angka2_2006 != 0, untuk mencegah terjadinya error ZeroDivisionError apabila angka2_2006 bernilai nol. Apabila angka2_2006 bernilai nol, program akan menampilkan pesan bahwa pembagian tidak dapat dilakukan melalui blok else.
#
# 7. Operator assignment perpangkatan (**=) diletakkan di luar struktur kondisi karena operasi perpangkatan tidak menimbulkan risiko pembagian dengan nol, sehingga dapat dijalankan langsung tanpa validasi tambahan.

# %% [markdown]
# ### 2.2.3 Program "Bitwise_2611532006"

# %%
# Buat file dengan nama bitwise_2611532006.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_2006
# Program ini menggunakan fungsi input()

print("\n==============================")
print("3. OPERATOR BITWISE")
print("==============================")

angka1_2006 = int(input("Masukkan angka bitwise-1: "))
angka2_2006 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =", angka1_2006, "| biner =", bin(angka1_2006))
print("angka2 =", angka2_2006, "| biner =", bin(angka2_2006))

# Bitwise AND
hasil_2006 = angka1_2006 & angka2_2006
print("\nBitwise AND (&)")
print(angka1_2006, "&", angka2_2006, "=", hasil_2006)
print("Biner hasil =", bin(hasil_2006))
print("Biner hasil (8 bit) =", format(hasil_2006, "08b"))

# Bitwise OR
hasil_2006 = angka1_2006 | angka2_2006
print("\nBitwise OR (|)")
print(angka1_2006, "|", angka2_2006, "=", hasil_2006)
print("Biner hasil =", bin(hasil_2006))
print("Biner hasil (8 bit) =", format(hasil_2006, "08b"))

# Bitwise XOR
hasil_2006 = angka1_2006 ^ angka2_2006
print("\nBitwise XOR (^)")
print(angka1_2006, "^", angka2_2006, "=", hasil_2006)
print("Biner hasil =", bin(hasil_2006))
print("Biner hasil (8 bit) =", format(hasil_2006, "08b"))

# Bitwise NOT
hasil_2006 = ~angka1_2006
print("\nBitwise NOT (~)")
print("~", angka1_2006, "=", hasil_2006)
print("Biner hasil =", bin(hasil_2006))
print("Biner hasil (8 bit) =", format(hasil_2006, "08b"))

# Bitwise geser kiri
jumlah_geser = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_2006 = angka1_2006 << jumlah_geser
print("\nBitwise geser kiri (<<)")
print(angka1_2006, "<<", jumlah_geser, "=", hasil_2006)
print("Biner hasil =", bin(hasil_2006))
print("Biner hasil (8 bit) =", format(hasil_2006, "08b"))

# Bitwise geser kanan
hasil_2006 = angka1_2006 >> jumlah_geser
print("\nBitwise geser kanan (>>)")
print(angka1_2006, ">>", jumlah_geser, "=", hasil_2006)
print("Biner hasil =", bin(hasil_2006))
print("Biner hasil (8 bit) =", format(hasil_2006, "08b"))

# %% [markdown]
# **Penjelasan :**
# 1. Program ini dibuat untuk mengimplementasikan operator bitwise pada Python, yaitu AND (&), OR (|), XOR (^), NOT (~), geser kiri (<<), dan geser kanan (>>), yang bekerja pada representasi biner dari suatu bilangan.
#
# 2. Seluruh nama variabel diberi akhiran _2006 sesuai empat digit terakhir NIM, sebagai identitas bahwa program dibuat oleh praktikan yang bersangkutan.
#
# 3. Fungsi input() digunakan untuk meminta pengguna memasukkan dua nilai, yaitu angka1_2006 dan angka2_2006, yang dikonversi menjadi tipe data integer menggunakan fungsi int(). Fungsi bin() digunakan untuk menampilkan representasi biner dari nilai desimal yang dimasukkan, sedangkan fungsi format(nilai, "08b") digunakan untuk menampilkan biner dalam format 8 bit.
#
# 4. Operator AND (&) menghasilkan bit 1 hanya jika kedua bit yang dibandingkan bernilai 1.
#
# 5. Operator OR (|) menghasilkan bit 1 apabila salah satu atau kedua bit yang dibandingkan bernilai 1.
#
# 6. Operator XOR (^) menghasilkan bit 1 apabila kedua bit yang dibandingkan berbeda nilai.
#
# 7. Operator NOT (~) membalikkan seluruh bit dari suatu bilangan sekaligus mengubah tandanya, karena Python menggunakan representasi two's complement, sesuai dengan rumus ~x = -(x+1).
#
# 8. Operator geser kiri (<<) menggeser seluruh bit ke arah kiri sebanyak jumlah yang ditentukan, yang secara matematis setara dengan mengalikan bilangan dengan 2 pangkat jumlah geseran.
#
# 9. Operator geser kanan (>>) menggeser seluruh bit ke arah kanan sebanyak jumlah yang ditentukan, yang setara dengan membagi bilangan dengan 2 pangkat jumlah geseran secara pembagian bulat.

# %% [markdown]
# ### 2.2.4 Program "Lainnya_2611532006"

# %%
# Buat file dengan nama Lainnya_2611532006.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_2006
# Program ini menggunakan funsgi input()
# Program operator keanggotaan dan identitas dalam python

print("==============================")
print("1. OPERATOR KEANGGOTAAN")
print("==============================")

# Input beberapa data yang dipisahkan dengan koma
input_data_2006 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_2006 = [int(angka.strip()) for angka in input_data_2006.split(",")]

nilai_dicari_2006 = int(input("Masukkan angka yang ingin dicari: "))

# Operator in
hasil = nilai_dicari_2006 in data_2006
print("\nOperator keanggotaan IN")
print(nilai_dicari_2006, "in", data_2006, "=", hasil)

# Operator not in
hasil = nilai_dicari_2006 not in data_2006
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_2006, "not in", data_2006, "=", hasil)

print("\n================================")
print("2. OPERATOR IDENTITAS")
print("================================")

# objek1 menggunakan list dari input pengguna
objek1_2006 = data_2006

# objek2 merujuk pada objek yang sama dengan objek1
objek2_2006 = objek1_2006

# objek3 memiliki isi sama, tetapi merupakan objek baru
objek3_2006 = data_2006.copy()

print("objek1 =", objek1_2006)
print("objek2 =", objek2_2006)
print("objek3 =", objek3_2006)

# Operator is
hasil = objek1_2006 is objek2_2006
print("\nOperator identitas IS")
print("objek1 is objek2 =", hasil)

# Operator is not
hasil = objek1_2006 is not objek3_2006
print("\nOperator identitas IS NOT")
print("objek1 is not objek3 =", hasil)

# Membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai")
print("objek1 is objek3 =", objek1_2006 is objek3_2006)
print("objek1 == objek3 =", objek1_2006 == objek3_2006)

# %% [markdown]
# **Penjelasan :**
# 1. Program ini dibuat untuk mengimplementasikan operator keanggotaan (in, not in) dan operator identitas (is, is not) pada Python.
#
# 2. Seluruh nama variabel diberi akhiran _2006 sesuai empat digit terakhir NIM, sebagai identitas bahwa program dibuat oleh praktikan yang bersangkutan.
#
# 3. Fungsi input() digunakan untuk meminta pengguna memasukkan beberapa angka yang dipisahkan dengan tanda koma. Data tersebut kemudian diolah menggunakan list comprehension, yaitu memecah string berdasarkan koma dengan metode split(","), menghilangkan spasi berlebih dengan strip(), lalu mengubah setiap elemen menjadi tipe data integer menggunakan int(), sehingga terbentuk sebuah list bertipe integer bernama data_2006.
#
# 4. Operator keanggotaan IN digunakan untuk memeriksa apakah suatu nilai terdapat di dalam list, dan akan menghasilkan nilai boolean True apabila nilai tersebut ditemukan.
#
# 5. Operator keanggotaan NOT IN digunakan untuk memeriksa apakah suatu nilai tidak terdapat di dalam list, dan akan menghasilkan nilai kebalikan dari operator IN.
#
# 6. Pada bagian operator identitas, objek2_2006 dibuat dengan cara menyalin referensi dari objek1_2006 (objek2_2006 = objek1_2006), sehingga keduanya menunjuk pada objek yang sama di dalam memori. Sebaliknya, objek3_2006 dibuat menggunakan method copy(), sehingga meskipun isinya sama, objek3_2006 merupakan objek baru yang berbeda secara identitas dari objek1_2006.
#
# 7. Operator identitas IS digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang benar-benar sama di memori, bukan sekadar memiliki nilai yang sama.
#
# 8. Operator identitas IS NOT digunakan untuk memeriksa apakah dua variabel tidak merujuk pada objek yang sama di memori.
#
# 9. Pada bagian akhir program, dilakukan perbandingan antara operator is dan operator ==, yang menunjukkan perbedaan mendasar antara keduanya: operator is membandingkan identitas atau alamat memori suatu objek, sedangkan operator == membandingkan nilai atau isi dari objek tersebut, meskipun kedua objek tersebut berbeda secara identitas.

# %% [markdown]
# ### 2.2.5 Program "Logika_2611532006"

# %%
# Buat file dengan nama Logika_2611532006.py
# Nama variabel ditambah 4 digit nim terakhir contoh: a1_2006
# Program ini menggunakan funsgi input()
# Program operator logika dalam python

# Memasukkan bilai boolean
# Inout tidak oeka terhadap huruf besar dan kecil
a1_2006 = input("Input nilai boolean-1 (True/False): ").strip().lower() == "true"
a2_2006 = input("Input nilai boolean-2 (True/False): ").strip().lower() == "true"

print("\nA1 =", a1_2006)
print("A2 =", a2_2006)

# Konjungsi : bernilai True jika keduanya true
hasil_2006 = a1_2006 and a2_2006
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil_2006)

# Disjungsi : bernilai True jika salah satunya true
hasil_2006 = a1_2006 or a2_2006
print("\nDisjungsi (OR)")
print("A1 or A2 =", hasil_2006)

# Negasi A1 : membalik nilai A1
hasil_2006 = not a1_2006
print("\nNegasi A1 (NOT)")
print("not A1 =", hasil_2006)

# Negasi A2 : membalik nilai A2
hasil_2006 = not a2_2006
print("\nNegasi A2 (NOT)")
print("not A2 =", hasil_2006)

# XOR : bernilai True jika kedua nilai berbeda
hasil_2006 = a1_2006 != a2_2006
print("\nDisjungsi Ekslusif (XOR)")
print("A1 XOR A2 =", hasil_2006)

# %% [markdown]
# 1. Program ini dibuat untuk mengimplementasikan operator logika pada Python, yaitu konjungsi (and), disjungsi (or), negasi (not), dan disjungsi eksklusif atau XOR.
#
# 2. Seluruh nama variabel diberi akhiran _2006 sesuai empat digit terakhir NIM, sebagai identitas bahwa program dibuat oleh praktikan yang bersangkutan.
#
# 3. Fungsi input() digunakan untuk meminta pengguna memasukkan dua nilai boolean dalam bentuk teks (True/False). Ekspresi .strip().lower() == "true" digunakan untuk menghilangkan spasi berlebih dan mengubah huruf menjadi kecil terlebih dahulu, sehingga input tidak peka terhadap penulisan huruf besar atau kecil, kemudian hasil perbandingan tersebut menghasilkan nilai boolean True atau False yang disimpan ke variabel a1_2006 dan a2_2006.
#
# 4. Operator konjungsi (and) menghasilkan nilai True hanya apabila kedua operand bernilai True, dan akan menghasilkan False apabila salah satu atau kedua operand bernilai False.
#
# 5. Operator disjungsi (or) menghasilkan nilai True apabila salah satu atau kedua operand bernilai True, dan hanya menghasilkan False apabila kedua operand bernilai False.
#
# 6. Operator negasi (not) digunakan untuk membalikkan nilai kebenaran suatu operand, sehingga nilai True akan menjadi False dan sebaliknya.
#
# 7. Operator XOR (disjungsi eksklusif) tidak tersedia secara langsung dalam Python, sehingga pada program ini diimplementasikan menggunakan operator perbandingan tidak sama dengan (!=), yang akan menghasilkan True apabila kedua nilai boolean berbeda, dan False apabila kedua nilai boolean sama.

# %% [markdown]
# ### 2.2.6 Program "Perbandingan_2611532006"

# %%
# Buat file dengan nama perbandingan_2611532006.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka_2006
# Program ini menggunakan funsgi input()
# Program operator perbandingan dalam python

angka1_2006 = int(input("Input angka-1: "))
angka2_2006 = int(input("Input angka-2: "))

# Lebih besar dari
hasil_2006 = angka1_2006 > angka2_2006
print("\nOperator lebih besar dari")
print("angka1 > angka2 =", hasil_2006)

# Lebih kecil dari
hasil_2006 = angka1_2006 < angka2_2006
print("\nOperator lebih kecil dari")
print("angka1 < angka2 =", hasil_2006)

# Lebih besar dari atau sama dengan
hasil_2006 = angka1_2006 >= angka2_2006
print("\nOperator lebih besar dari atau sama dengan")
print("angka1 >= angka2 =", hasil_2006)

# Lebih kecil dari atau sama dengan
hasil_2006 = angka1_2006 <= angka2_2006
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1 <= angka2 =", hasil_2006)

# Sama dengan
hasil_2006 = angka1_2006 == angka2_2006
print("\nOperator Sama dengan")
print("angka1 == angka2 =", hasil_2006)

# Tidak sama dengan
hasil_2006 = angka1_2006 != angka2_2006
print("\nOperator Tidak sama dengan")
print("angka1 != angka2 =", hasil_2006)

# Tambahan : Perbandingan berantai dalam python
hasil_2006 = 0 < angka1_2006 < 100
print("\nOperator Perbandingan berantai")
print("0 < angka1 < 100 =", hasil_2006)

hasil_2006 = 0 < angka2_2006 < 100
print("0 < angka2 < 100 =", hasil_2006)

# %% [markdown]
# 1. Program ini dibuat untuk mengimplementasikan operator perbandingan pada Python, yaitu lebih besar dari (>), lebih kecil dari (<), lebih besar dari atau sama dengan (>=), lebih kecil dari atau sama dengan (<=), sama dengan (==), dan tidak sama dengan (!=).
#
# 2. Seluruh nama variabel diberi akhiran _2006 sesuai empat digit terakhir NIM, sebagai identitas bahwa program dibuat oleh praktikan yang bersangkutan.
#
# 3. Fungsi input() digunakan untuk meminta pengguna memasukkan dua nilai, yaitu angka1_2006 dan angka2_2006, yang dikonversi menjadi tipe data integer menggunakan fungsi int().
#
# 4. Operator perbandingan >, <, >=, dan <= digunakan untuk membandingkan besar kecilnya dua nilai, dan masing-masing menghasilkan nilai boolean True atau False sesuai dengan hasil perbandingannya.
#
# 5. Operator sama dengan (==) digunakan untuk memeriksa apakah dua nilai memiliki besaran yang sama, dan berbeda dengan operator penugasan (=) yang berfungsi memberikan nilai ke suatu variabel. Kesalahan penulisan == menjadi = akan mengubah maksud program dari operasi perbandingan menjadi operasi penugasan.
#
# 6. Operator tidak sama dengan (!=) digunakan untuk memeriksa apakah dua nilai memiliki besaran yang berbeda, dan akan menghasilkan nilai kebalikan dari operator ==.
#
# 7. Pada bagian akhir program, terdapat penerapan perbandingan berantai (chained comparison), yaitu penulisan lebih dari satu operator perbandingan dalam satu ekspresi seperti 0 < angka1_2006 < 100. Ekspresi tersebut setara dengan (0 < angka1_2006) and (angka1_2006 < 100), yang bernilai True apabila kedua syarat terpenuhi sekaligus.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal : Merancang sebuah program konsol sederhana yang mencatat data identitas praktikan baru dan melakukan verifikasi status kelulusan awal praktikum secara otomatis**
#
# <div align="center">
# <img src="images/soal_tugas3.png" width="500"><br>
# <em>Gambar 2.2 :  Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program

# %%
# Program Sistem Simulasi Transaksi dan Validasi Akses Toko

print("=== SISTEM TRANSAKSI TOKO ===")
nama_2006 = input("Masukkan nama pelanggan:")
status_pelanggan_2006 = input("Masukkan status pelanggan (member/non-member):").strip().lower()
total_belanja_2006 = int(input("Masukkan total belanja:"))
jumlah_barang_2006 = int(input("Masukkan jumlah barang:"))
kode_promo_2006 = input("Masukkan kode promo:")

print("\n=== DATA TRANSAKSI ===")
print("Nama Pelanggan :", nama_2006)
print("Total Belanja  : Rp", total_belanja_2006)
print("Jumlah Barang  :", jumlah_barang_2006)
print("Kode Promo     :", kode_promo_2006)

print("\n=== HASIL VALIDASI TRANSAKSI ===")
syarat_belanja_2006 = total_belanja_2006 >= 100000
syarat_barang_2006 = jumlah_barang_2006 >= 5
syarat_status_member_2006 = status_pelanggan_2006 == "member"
tersedia_promo_2006 = kode_promo_2006 != ""
syarat_diskon_2006 = syarat_status_member_2006 and syarat_belanja_2006
daftar_promo_2006 = ["SALE20", "PROMO20", "HEMAT20"]
syarat_promo_2006 = kode_promo_2006 in daftar_promo_2006
 
print("Belanja >= Rp100000 :", syarat_belanja_2006) 
print("Jumlah Barang >= 5  :", syarat_barang_2006)
print("Status Member       :", syarat_status_member_2006)
print("Kode Promo Tersedia :", tersedia_promo_2006)
print("Mendapatkan Diskon  :", syarat_diskon_2006)
print("Mendapatkan Promo   :", syarat_promo_2006)

print("\n=== HASIL PERHITUNGAN ===")
diskon_2006 = 0
if syarat_diskon_2006:
    diskon_2006 = total_belanja_2006 * 20 // 100
    print("Diskon 20%            :Rp", diskon_2006)
total_bayar_2006 = total_belanja_2006 - diskon_2006
rata_rata_barang_2006 = total_bayar_2006 // jumlah_barang_2006
print("Total Bayar            :Rp", total_bayar_2006)
print("Rata-rata Harga Barang :Rp", rata_rata_barang_2006)

print("\n=== HAK AKSES PELANGGAN ===")
member_akses_2006 = syarat_status_member_2006
promo_akses_2006 = syarat_promo_2006 and syarat_belanja_2006
free_shipping_akses_2006 = syarat_status_member_2006 and syarat_barang_2006
member_bit_2006 = 0b0001
belanja_bit_2006 = 0b0010
barang_bit_2006 = 0b0100
promo_bit_2006 = 0b1000
kode_hak_akses_2006 = 0
if syarat_status_member_2006:
    kode_hak_akses_2006 = kode_hak_akses_2006 | member_bit_2006
if syarat_belanja_2006 :
    kode_hak_akses_2006 = kode_hak_akses_2006 | belanja_bit_2006
if syarat_barang_2006 :
    kode_hak_akses_2006 = kode_hak_akses_2006 | barang_bit_2006
if syarat_promo_2006:
    kode_hak_akses_2006 = kode_hak_akses_2006 | promo_bit_2006
print("Kode Hak Akses       :", format(kode_hak_akses_2006,"04b"))
print("Member Access        :", member_akses_2006)
print("Promo Access         :", promo_akses_2006)
print("Free Shipping Access :", free_shipping_akses_2006)

print("\n=== OPERASI BITWISE ===")
print("=== Kode Status Transaksi ===")
print("Kode Biner   :", format(kode_hak_akses_2006, "04b"))
print("Kode Desimal :", kode_hak_akses_2006)

print("=== Pemeriksaan Status ===")
print("Cek Member")
print(format(kode_hak_akses_2006,"04b"), '&', "0001")
status_member_2006 = kode_hak_akses_2006 & member_bit_2006
print("Hasil Biner   :", format(status_member_2006,"04b"))
print("Hasil Desimal :", status_member_2006)
print("\nCek Promo")
print(format(kode_hak_akses_2006,"04b"), '&', "1000")
status_promo_2006 = kode_hak_akses_2006 & promo_bit_2006
print("Hasil Biner   :", format(status_promo_2006,"04b"))
print("Hasil Desimal :", status_promo_2006)
print("\nCek Belanja")
print(format(kode_hak_akses_2006,"04b"), '&', "0010")
status_belanja_2006 = kode_hak_akses_2006 & belanja_bit_2006
print("Hasil Biner   :", format(status_belanja_2006,"04b"))
print("Hasil Desimal :", status_belanja_2006)
print("\nCek Barang")
print(format(kode_hak_akses_2006,"04b"), '&', "0100")
status_barang_2006 = kode_hak_akses_2006 & barang_bit_2006
print("Hasil Biner   :", format(status_barang_2006,"04b"))
print("Hasil Desimal :", status_barang_2006)

print("\n=== Perbandingan Status ===")
kode_referensi_2006 = 0b1001
print("Kode Transaksi:", format(kode_hak_akses_2006,"04b"))
print("Kode Referensi:", format(kode_referensi_2006,"04b"))
print(format(kode_hak_akses_2006,"04b"), '^', "1001")
perbandingan_status_2006 = kode_hak_akses_2006 ^ kode_referensi_2006
print("Hasil Biner  :", format(perbandingan_status_2006,"04b"))
print("Hasil Desimal:", perbandingan_status_2006)

print("=== Shift ===")
#geser kiri
print(format(kode_hak_akses_2006,"04b"),'<<',"1")
hasil_shift_2006 = kode_hak_akses_2006 << 1
print("Hasil Biner:", format(hasil_shift_2006,"04b"))
print("Hasil Desimal:", hasil_shift_2006)
#geser kanan
print(format(kode_hak_akses_2006,"04b"),'>>',"1")
hasil_shift_2006 = kode_hak_akses_2006 >> 1
print("Hasil Biner:", format(hasil_shift_2006,"04b"))
print("Hasil Desimal:", hasil_shift_2006)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_tugas3.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :** 1. Program ini dibuat untuk mensimulasikan sistem transaksi dan validasi hak akses pelanggan toko, dengan menggabungkan operator perbandingan, logika, aritmatika, assignment, dan bitwise dalam satu program yang utuh.
#
# 2. Seluruh nama variabel diberi akhiran _2006 sesuai empat digit terakhir NIM, sebagai identitas bahwa program dibuat oleh praktikan yang bersangkutan.
#
# 3. Fungsi input() digunakan untuk menerima lima data dari pengguna, yaitu nama pelanggan, status pelanggan, total belanja, jumlah barang, dan kode promo, dengan total belanja dan jumlah barang dikonversi menjadi tipe data integer menggunakan int().
#
# 4. Pada bagian validasi transaksi, digunakan operator perbandingan (>=, ==, !=, in) untuk memeriksa beberapa syarat sekaligus, yaitu apakah belanja mencapai Rp100.000, jumlah barang minimal 5, status pelanggan adalah member, kode promo diisi, dan apakah kode promo yang dimasukkan terdapat di dalam daftar_promo_2006 menggunakan operator keanggotaan in.
#
# 5. Operator logika and digunakan untuk menggabungkan dua syarat sekaligus dalam menentukan kelayakan diskon (syarat_status_member_2006 and syarat_belanja_2006) serta kelayakan promo dan free shipping, sehingga suatu syarat gabungan hanya bernilai True apabila seluruh syarat penyusunnya terpenuhi.
#
# 6. Pada bagian perhitungan, operator aritmatika perkalian dan pembagian bulat (* dan //) digunakan untuk menghitung nilai diskon sebesar 20% dari total belanja apabila syarat_diskon_2006 bernilai True, kemudian operator pengurangan (-) digunakan untuk menghitung total pembayaran akhir, dan operator // kembali digunakan untuk menghitung rata-rata harga barang agar hasilnya berupa bilangan bulat.
#
# 7. Pada bagian hak akses pelanggan, digunakan empat konstanta bit (member_bit_2006, belanja_bit_2006, barang_bit_2006, promo_bit_2006) yang masing-masing bernilai 0001, 0010, 0100, dan 1000. Operator bitwise OR (|) digunakan untuk menyalakan bit tertentu ke dalam variabel kode_hak_akses_2006 apabila syarat yang bersesuaian terpenuhi, sehingga kode tersebut merepresentasikan kombinasi seluruh status pelanggan dalam satu nilai biner 4 digit.
#
# 8. Pada bagian operasi bitwise, operator AND (&) digunakan untuk memeriksa kembali apakah bit tertentu aktif di dalam kode_hak_akses_2006, dengan cara mengoperasikan kode tersebut terhadap masing-masing bit acuan (member_bit_2006, belanja_bit_2006, barang_bit_2006, dan promo_bit_2006). Hasil AND yang bukan nol menandakan bit tersebut aktif, sedangkan hasil nol menandakan bit tersebut tidak aktif.
#
# 9. Operator XOR (^) digunakan untuk membandingkan kode_hak_akses_2006 dengan sebuah kode_referensi_2006 (1001) yang bersifat tetap, di mana setiap posisi bit yang berbeda antara kedua kode tersebut akan menghasilkan nilai 1, sehingga XOR dapat digunakan untuk mendeteksi perbedaan status transaksi pelanggan terhadap suatu standar acuan.
#
# 10. Operator geser kiri (<<) dan geser kanan (>>) digunakan untuk menggeser seluruh posisi bit pada kode_hak_akses_2006, yang secara matematis setara dengan mengalikan (<<) atau membagi (>>) nilai desimalnya dengan pangkat dua sesuai jumlah pergeseran yang dilakukan.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# 1. Operator merupakan simbol atau kata kunci khusus yang digunakan untuk melakukan suatu operasi terhadap satu atau lebih nilai (operand), dan setiap jenis operator memiliki fungsi serta aturan penulisan yang berbeda-beda.
#
# 2. Operator aritmatika (+, -, *, /, //, %, **) digunakan untuk melakukan perhitungan matematis, dengan operator / selalu menghasilkan tipe data float, sedangkan // menghasilkan hasil bagi bulat dan % menghasilkan sisa bagi.
#
# 3. Operator penugasan (=, +=, -=, *=, /=, //=, %=, **=) digunakan untuk memberikan atau memperbarui nilai suatu variabel, di mana bentuk gabungan seperti += terbukti menghasilkan nilai akhir yang sama dengan operator aritmatika biasa namun dengan penulisan kode yang lebih ringkas.
#
# 4. Operator perbandingan (>, <, >=, <=, ==, !=) digunakan untuk membandingkan dua nilai dan menghasilkan tipe data boolean, serta perlu diperhatikan perbedaan mendasar antara operator == (perbandingan) dan = (penugasan) agar tidak menimbulkan kesalahan logika pada program.
#
# 5. Operator logika (and, or, not) digunakan untuk menggabungkan atau membalikkan nilai kebenaran dari suatu ekspresi kondisional, sedangkan operasi XOR dapat diimplementasikan menggunakan operator perbandingan tidak sama dengan (!=) karena Python tidak menyediakan operator XOR logika secara langsung.
#
# 6. Operator bitwise (&, |, ^, ~, <<, >>) bekerja pada representasi biner suatu bilangan, di mana operator << dan >> masing-masing setara dengan perkalian dan pembagian bilangan dengan pangkat dua.
#
# 7. Operator keanggotaan (in, not in) digunakan untuk memeriksa keberadaan suatu nilai di dalam struktur data seperti list, sedangkan operator identitas (is, is not) digunakan untuk memeriksa kesamaan objek berdasarkan alamat memori, bukan berdasarkan nilai seperti pada operator ==.
#
# 8. Berdasarkan seluruh percobaan yang telah dilakukan, dapat disimpulkan bahwa pemahaman terhadap jenis, fungsi, dan cara kerja setiap operator sangat penting dalam penyusunan program, karena kesalahan kecil dalam penulisan operator, seperti tertukarnya operator = dengan ==, dapat menyebabkan program berjalan tanpa error namun menghasilkan keluaran yang tidak sesuai dengan yang diharapkan.
#
# 9. Praktikum ini telah memenuhi tujuan yang ditetapkan, yaitu memahami konsep operator dan operand, membedakan jenis-jenis operator pada Python, mengimplementasikannya ke dalam program menggunakan Jupyter Notebook, serta menganalisis hasil keluaran dan pengaruh presedensi operator terhadap suatu ekspresi.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# Lutz, M. (2013). Learning Python (5th ed.). O'Reilly Media.
#
# Matthes, E. (2019). Python Crash Course: A Hands-On, Project-Based Introduction to Programming (2nd ed.). No Starch Press.
#
# Python Software Foundation. (2024). The Python Standard Library — Built-in Types. Diakses dari https://docs.python.org/3/library/stdtypes.html
#
# Python Software Foundation. (2024). The Python Language Reference — Expressions. Diakses dari https://docs.python.org/3/reference/expressions.html
